# %% [markdown]
# ## Problem_07 ##

# %%
def count_nucleotides(string):
    counts = {'A': 0, 'C': 0, 'G': 0, 'T': 0}
    
    for nucleotide in string:
        counts[nucleotide] += 1

        
    return counts['A'], counts['C'], counts['G'], counts['T'] 


string = "..."
result = count_nucleotides(string)
print(*result)
# Out:
# 219 222 250 247

# %% [markdown]
# ## Problem_08 ##

# %%
def reverse_basepairs(string):
    complement = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}
    reverse_complement = ''
    for nucleotide in string:
        reverse_complement += complement[nucleotide]
    return reverse_complement[::-1]

string = "..."
result = reverse_basepairs(string)
print(result)
# Out:
# ...
